# %% [markdown]
# <a href="https://colab.research.google.com/github/Lonelyhaker903/FMML-LABS/blob/main/Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 16:02:55--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   143MB/s    in 0.5s
#
# 2024-03-30 16:02:56 (143 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 35849   1301.5349v1  This paper presents our experience regarding t...    cs
# 26685  1611.06362v1  Recent years have witnessed extensive attentio...    cs
# 18953   1301.3868v1  To investigate the robustness of the output pr...    cs
# 40809   1403.2484v1  This paper addresses the problem of transferri...    cs
# 4298   1801.03523v1  The present paper aims to demonstrate the usag...  stat
# ...             ...                                                ...   ...
# 27421  1703.06260v1  Image super-resolution using self-optimizing m...    cs
# 15102   1403.4467v2  Sign Language (SL) linguistic is dependent on ...    cs
# 22058   1407.7969v1  We introduce a means of automating machine lea...  stat
# 6960   1708.02511v2  Generative modeling of high dimensional data l...    cs
# 5373    1306.1433v3  We give the proof of a tight lower bound on th...    cs
#
#                                                    title  year  \
# 35849  Toward the Automatic Generation of a Semantic ...  2013
# 26685  Ordinal Constrained Binary Code Learning for N...  2016
# 18953  Making Sensitivity Analysis Computationally Ef...  2013
# 40809  Transfer Learning across Networks for Collecti...  2014
# 4298   Generative Models for Stochastic Processes Usi...  2018
# ...                                                  ...   ...
# 27421  Single image super-resolution using self-optim...  2017
# 15102         A hybrid formalism to parse Sign Languages  2014
# 22058  Automated Machine Learning on Big Data using S...  2014
# 6960   Parametric Adversarial Divergences are Good Ta...  2017
# 5373   Tight Lower Bound on the Probability of a Bino...  2013
#
#                                                 keywords
# 35849  [experience, regarding, unorganized, knowledge...
# 26685  [witnessed, extensive, attention, dimensional,...
# 18953  [investigate, robustness, probabilities, sensi...
# 40809  [addresses, transferring, knowledge, primarily...
# 4298   [demonstrate, convolutional, generative, stoch...
# ...                                                  ...
# 27421  [resolution, optimizing, fractional, interpola...
# 15102  [linguistic, dependent, expensive, annotating,...
# 22058  [introduce, automating, performing, stochastic...
# 6960   [generative, dimensional, notoriously, difficu...
# 5373   [probability, inequality, important, including...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 35849    [experience, regarding, unorganized, knowledge...
# 26685    [witnessed, extensive, attention, dimensional,...
# 18953    [investigate, robustness, probabilities, sensi...
# 40809    [addresses, transferring, knowledge, primarily...
# 4298     [demonstrate, convolutional, generative, stoch...
#                                ...
# 204      [introducing, information, intermediate, algor...
# 6005     [obtaining, consuming, algorithm, intelligentl...
# 11708    [characterizes, averaging, techniques, conjunc...
# 23051    [distributional, approaches, reinforcement, di...
# 6935     [relational, probabilistic, challenge, aggrega...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8788 words.
# Out of those 4553 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a04017be-d93c-4dd9-b38a-55a357e4d4e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a04017be-d93c-4dd9-b38a-55a357e4d4e3")) {                    Plotly.newPlot(                        "a04017be-d93c-4dd9-b38a-55a357e4d4e3",                        [{"x":["intelligent","combining","unorganized","resulting","annotations","contained","experience","specialists","geometrical","knowledge","generation","processing","materialized","therefore","visualized","regarding","topological","automatic","presented","populated","detection","technical","combination","prototype","annotation","similarity","constraints","quadratic","dimensional","constrained","attention","experimental","approximation","retrieval","efficiently","benchmark","preserves","quantized","relations","effectively","promising","constraint","approaches","projection","preserving","efficient","extensive","performance","algorithm","stochastic","functions","expensive","particular","optimization","witnessed","parameters","sensitivity","conversely","investigate","establishes","probability","computing","propagation","performed","coefficients","parameter","establishing","robustness","posterior","evaluations","probabilities","marginals","computationally","expressing","addresses","experiments","identically","information","dependent","thereafter","successfully","collective","distributed","primarily","discovers","classifying","different","classification","correlations","instances","demonstrate","relationships","constructing","structure","transferring","leverages","transferred","iterative","independent","processes","convolutional","forecasts","quantitative","simulations","generative","researchers","variation","identification","resources","disparity","eliminates","containing","dependency","demographic","linguistic","investigating","classifier","distantly","associated","increasingly","supervised","demographics","conversational","developing","demonstrating","phenomena","dialectal","represent","consistency","translating","abductive","inconsistency","adaptation","minimally","inconsistent","management","procedure","situation","variables","polynomial","exponential","restricted","introduce","independently","correctness","observable","equivalence","including","guarantees","complexity","distribution","potentially","optimality","generally","asymptotic","selective","invariant","systematic","direction","statistically","framework","disparate","prediction","theoretic","distributions","recidivism","attribute","correction","indistinguishable","discrimination","illustrate","divergence","sensitive","expression","application","introduced","qualitative","elicitation","reasoning","appropriately","techniques","preference","facilitating","considered","extension","equilibria","preferences","developed","strategic","formalisms","conditional","challenging","comprehensive","predicate","combinatorial","effectiveness","relationship","extraction","translation","embedding"],"y":[58,106,2,153,59,24,34,1,11,342,152,272,3,141,5,38,17,182,189,6,367,40,136,23,51,141,147,34,187,87,174,399,133,109,178,230,22,9,91,108,118,80,436,47,62,397,186,893,825,128,224,65,278,332,9,236,33,9,150,15,180,153,64,152,37,110,14,101,40,59,74,5,94,16,58,597,4,730,60,6,87,26,108,19,20,48,717,545,32,107,573,71,42,357,14,26,10,73,118,102,397,4,76,46,120,72,54,112,70,11,8,71,49,9,58,16,138,4,120,54,203,3,16,62,44,27,4,123,54,10,6,8,66,5,16,53,94,29,117,57,41,45,353,54,23,19,25,262,68,223,204,54,18,60,14,22,68,30,52,20,560,7,230,48,117,1,31,25,7,15,84,28,62,38,233,134,57,7,123,11,375,27,3,127,83,6,33,190,11,6,80,285,64,9,42,220,79,131,107,118],"type":"bar"},{"x":["intelligent","combining","unorganized","resulting","annotations","contained","exper ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4553,), (4553, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8058333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Food</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Ingredients</span> <span style='background-color:rgba(0, 255, 0, 0.6576200417536534);'>Recognition</span> <span style=''>through</span> <span style=''>Multi</span> <span style=''>label</span> <span style=''>Learning</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.4015151515151516);'>Automatically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructing</span> <span style=''>a</span> <span style=''>food</span> <span style=''>diary</span> <span style=''>that</span> <span style=''>tracks</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ingredients</span> <span style=''>consumed</span> <span style=''>can</span> <span style=''>help</span> <span style=''>people</span> <span style=''>follow</span> <span style=''>a</span> <span style=''>healthy</span> <span style=''>diet</span> <span style=''>We</span> <span style=''>tackle</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>food</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ingredients</span> <span style='background-color:rgba(0, 255, 0, 0.6576200417536534);'>recognition</span> <span style=''>as</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>label</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style=''>adapting</span> <span style=''>a</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>CNN</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>act</span> <span style=''>as</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictor</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>recipes</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>their</span> <span style=''>list</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ingredients</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>our</span> <span style=''>model</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>given</span> <span style=''>a</span> <span style=''>picture</span> <span style=''>predict</span> <span style=''>its</span> <span style=''>list</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ingredients</span> <span style=''>even</span> <span style=''>if</span> <span style=''>the</span> <span style=''>recipe</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>the</span> <span style=''>picture</span> <span style=''>has</span> <span style=''>never</span> <span style=''>been</span> <span style=''>seen</span> <span style=''>by</span> <span style=''>the</span> <span style=''>model</span> <span style=''>We</span> <span style=''>make</span> <span style=''>public</span> <span style=''>two</span> <span style=''>new</span> <span style=''>datasets</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>this</span> <span style=''>purpose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>a</span> <span style=''>model</span> <span style=''>trained</span> <span style=''>with</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>v ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Log</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Determinants</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>Kernel</span> <span style=''>Learning</span> <br/><br/><span style=''>For</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>as</span> <span style=''>varied</span> <span style=''>as</span> <span style=''>Bayesian</span> <span style=''>neural</span> <span style=''>networks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determinantal</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>elliptical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>and</span> <span style=''>kernel</span> <span style=''>learning</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>(GPs)</span> <span style=''>one</span> <span style=''>must</span> <span style=''>compute</span> <span style=''>a</span> <span style=''>log</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determinant</span> <span style=''>of</span> <span style=''>an</span> <span style=''>n</span> <span style=''>times</span> <span style=''>n</span> <span style=''>positive</span> <span style=''>definite</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>derivatives</span> <span style=''>leading</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prohibitive</span> <span style=''>mathcalO(n3)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computations</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>novel</span> <span style=''>mathcalO(n)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantities</span> <span style=''>from</span> <span style=''>only</span> <span style=''>fast</span> <span style=''>matrix</span> <span style=''>vector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiplications</span> <span style=''>(MVMs)</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Chebyshev</span> <span style=''>Lanczos</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surrogate</span> <span style=''>models</span> <span style=''>and</span> <span style=''>converge</span> <span style=''>quickly</span> <span style=''>even</span> <span style=''>for</span> <span style=''>kernel</span> <span style=''>matrices</span> <span style=''>that</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>spectra</span> <span style=''>We</span> <span style=''>leverage</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>scalable</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>kernel</span> <span style=''>learning</span> <span style=''>We</span> <span style=''>find</span> <span style=''>that</span> <span style=''>Lanczos</span> <span style=''>is</span> <span style='background-color:rgba(0, 2 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Exponential</span> <span style=''>Families</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conditional</span> <span style=''>Random</span> <span style=''>Fields</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>de</span> <span style=''>ne</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>random</span> <span style=''>elds</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.8367346938775511);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>spaces</span> <span style=''>and</span> <span style=''>show</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connections</span> <span style=''>to</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>classi</span> <span style=''>cation</span> <span style=''>More</span> <span style=''>speci</span> <span style=''>cally</span> <span style=''>we</span> <span style=''>prove</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>results</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.37142857142857144);'>undirected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>and</span> <span style=''>we</span> <span style=''>give</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructions</span> <span style=''>for</span> <span style=''>kernels</span> <span style=''>Finally</span> <span style=''>we</span> <span style=''>present</span> <span style=''>e</span> <span style=''>cient</span> <span style=''>means</span> <span style=''>of</span> <span style=''>solving</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>using</span> <span style=''>reduced</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.5652173913043479);'>decompositions</span> <span style=''>and</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationarity</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3650793650793651);'>exploited</span> <span style=''>e</span> <span style=''>ciently</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>process</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Greedy</span> <span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>via</span> <span style=''>Weak</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Submodularity</span> <br/><br/><span style=''>Greedy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>for</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>such</span> <span style=''>as</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>and</span> <span style=''>set</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unfortunately</span> <span style=''>for</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>the</span> <span style=''>running</span> <span style=''>time</span> <span style=''>of</span> <span style=''>even</span> <span style=''>greedy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>can</span> <span style=''>be</span> <span style=''>quite</span> <span style=''>high</span> <span style=''>This</span> <span style=''>is</span> <span style=''>because</span> <span style=''>for</span> <span style=''>each</span> <span style=''>greedy</span> <span style=''>step</span> <span style=''>we</span> <span style=''>need</span> <span style=''>to</span> <span style=''>refit</span> <span style=''>a</span> <span style=''>model</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculate</span> <span style=''>a</span> <span style=''>function</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>previously</span> <span style=''>selected</span> <span style=''>choices</span> <span style=''>and</span> <span style=''>the</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style=''>Two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>are</span> <span style=''>faster</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>to</span> <span style=''>the</span> <span style=''>greedy</span> <span style=''>forward</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>were</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>recently</span> <span style=''>(Mirzasoleiman</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2013</span> <span style=''>2015)</span> <span style=''>They</span> <span style=''>achieve</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploiting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>respectively</span> <span style=''>Both</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>provable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>submodular</span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09648811635331678)
# 	segmentation (0.0716566158212132)
# 	experimental (0.14153955303299043)
# 	architecture (0.0957786449095424)
# 	representation (0.13905640297978006)
# 	information (0.25895707697765163)
# 	different (0.2543455125931181)
# 	detection (0.1301880099326002)
# 	convolutional (0.14083008158921603)
# 	recognition (0.14083008158921603)
#
# Some Statistics words are:
# 	variables (0.12973245835436648)
# 	stochastic (0.1347804139323574)
# 	algorithm (0.38768298838970217)
# 	statistical (0.15850580514891469)
# 	theoretical (0.15598182735991922)
# 	estimation (0.18223119636547197)
# 	distribution (0.18273599192327108)
# 	inference (0.20797576981322563)
# 	dimensional (0.19535588086824837)
# 	regression (0.1746592629984856)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="819c1927-ea59-4406-8129-317b2aeceffd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("819c1927-ea59-4406-8129-317b2aeceffd")) {                    Plotly.newPlot(                        "819c1927-ea59-4406-8129-317b2aeceffd",                        [{"x":["intelligent","combining","unorganized","resulting","annotations","contained","experience","specialists","geometrical","knowledge","generation","processing","materialized","therefore","visualized","regarding","topological","automatic","presented","populated","detection","technical","combination","prototype","annotation","similarity","constraints","quadratic","dimensional","constrained","attention","experimental","approximation","retrieval","efficiently","benchmark","preserves","quantized","relations","effectively","promising","constraint","approaches","projection","preserving","efficient","extensive","performance","algorithm","stochastic","functions","expensive","particular","optimization","witnessed","parameters","sensitivity","conversely","investigate","establishes","probability","computing","propagation","performed","coefficients","parameter","establishing","robustness","posterior","evaluations","probabilities","marginals","computationally","expressing","addresses","experiments","identically","information","dependent","thereafter","successfully","collective","distributed","primarily","discovers","classifying","different","classification","correlations","instances","demonstrate","relationships","constructing","structure","transferring","leverages","transferred","iterative","independent","processes","convolutional","forecasts","quantitative","simulations","generative","researchers","variation","identification","resources","disparity","eliminates","containing","dependency","demographic","linguistic","investigating","classifier","distantly","associated","increasingly","supervised","demographics","conversational","developing","demonstrating","phenomena","dialectal","represent","consistency","translating","abductive","inconsistency","adaptation","minimally","inconsistent","management","procedure","situation","variables","polynomial","exponential","restricted","introduce","independently","correctness","observable","equivalence","including","guarantees","complexity","distribution","potentially","optimality","generally","asymptotic","selective","invariant","systematic","direction","statistically","framework","disparate","prediction","theoretic","distributions","recidivism","attribute","correction","indistinguishable","discrimination","illustrate","divergence","sensitive","expression","application","introduced","qualitative","elicitation","reasoning","appropriately","techniques","preference","facilitating","considered","extension","equilibria","preferences","developed","strategic","formalisms","conditional","challenging","comprehensive","predicate","combinatorial","effectiveness","relationship","extraction","translation","embedding","relational","representation","connecting","inference","competitive","understanding","predictions","hyperparameters","proposing","accurately","expressions","uncertainty","correlation","analytically","expressive","forecasting","approximations","reconstruction","celebrated","optimisation","respectively","nonlinear","experiment","likelihood","numerical","nonparametric","interpretability","meaningful","transformation","covariance","derivative","conceivable","efficiency","sufficient","functional","generates","synthetic","graphical","statistical","coordinate","necessary","available","providing","resonance","validation","convergent","solutions","properties","neighborhoods","generalize","convergence","constructions","assumption","smoothness","constructio ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	asymptotics
# 	robustification
# 	emphmulti
# 	metastable
# 	supermarket
# 	lindenstrauss
# 	expectimax
# 	nonconjugate
# 	schizophrenia
# 	psychiatric
# 	approachable
# 	transparency
# 	consonants
# 	influencing
# 	abstention
# 	binarycategorical
# 	parameterizing
# 	signaling
# 	looseness
# 	mismatched
# Some words which never appear in Statistics papers:
# 	unorganized
# 	materialized
# 	populated
# 	thereafter
# 	distantly
# 	demographics
# 	conversational
# 	dialectal
# 	abductive
# 	formalisms
# 	phenotypic
# 	evidential
# 	visibility
# 	coalition
# 	surpassed
# 	unrealistically
# 	occlusions
# 	articulations
# 	accordance
# 	incompleteness

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0540878966496655e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
